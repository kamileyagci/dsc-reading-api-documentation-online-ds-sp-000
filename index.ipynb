# %% [markdown]
# # Reading API Documentation
#
# ## Introduction
# We've now covered an example API request, but how on Earth would you know how to do that on your own? The answer is through documentation! All APIs will have associated documentation, and while there are substantial similarities, all will be different to one degree or another. The best way to get more comfortable is to practice! So with that, let's take a look at the yelp documentation associated with our previous example.
#
# ## Objectives
#
# You will be able to:
#
# * Interpret API documentation into Python code
# * Make requests using OAuth
#
# Start by navigating to https://www.yelp.com/developers/documentation/v3/get_started and having a look for yourself!
#
# <img src="images/yelp_overview.png" width="800">
#
# As you see at the top, the first piece of almost every API is authentication.
#
# This is where we started in the previous codealong, where we went to https://www.yelp.com/developers/v3/manage_app and created a new app.
#
# <img src="images/yelp_app.png"  width="800">

# %% [markdown]
# Let's take a closer look at Yelp's authentication documentation:
# https://www.yelp.com/developers/documentation/v3/authentication
#
# <img src="images/yelp_auth.png" width="800">

# %% [markdown]
# Notice in the documentation, it gives us the specific format "Put the API Key in the request header as "Authorization: Bearer <YOUR API KEY>"." This is what we passed in our get request.
#
#
# Before we do this, let's import your authentication token which you have appropriately stored in **a separate file** from the codealong before.

# %%
import json

#Our previous function for loading our api key file
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %% [markdown]
# > **Note**: Like before, change the file path below to be your root directory.
# If you're not sure what your username is, check it with `pwd`
# For example, my current working directory is ```/Users/matthew.mitchell/Documents/dsc-using-yelp-api-codealong```
# So the line below would become:
# ```keys = get_keys("/Users/matthew.mitchell/.secret/yelp_api.json")```

# %%
keys = get_keys("/Users/kamileyagci/DataScienceBootcamp/.secret/yelp_api.json")

api_key = keys['api_key']

#While you may wish to print out these api keys to check that they imported properly,
#be sure to clear the output before uploading to Github. 
#Again, you don't want your keys stolen!!!

# %%
import requests

# %%
url = #This will be our next step
header = {"Authorization" : "Bearer {}".format(api_key)}
response = requests.get(url, header=header)
# Out:
#   File "<ipython-input-4-99271e4af878>", line 1
#     url = #This will be our next step
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
#  With that, let's take a look at how the rest of our request should be formatted. Go to https://www.yelp.com/developers/documentation/v3/business_search  and take a couple of minutes to look things over.
#
#  <img src="images/yelp_docs.png"  width="800">

# %% [markdown]
# Notice the first part is the format of the get request! This is the URL we pass into our get request. From there, the available parameters that you can pass are listed. These define your query, some are required while others are optional.
#
# Reviewing our python package we thus have:

# %%
url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {
                'location': 'NYC',
                'limit': 50
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
import pandas as pd
df = pd.DataFrame.from_dict(response.json()['businesses'])
print(len(df))
df
# Out:
# 50
#                         id                                           alias  \
# 0   H4jJ7XB3CetIr1pg56CczQ                          levain-bakery-new-york
# 1   V7lXZKBDzScDeGB8JmnzSA                     katzs-delicatessen-new-york
# 2   44SY464xDHbvOcjDzRbKkQ                            ippudo-ny-new-york-7
# 3   xEnNFXtMLDF5kZDxfaCJgA                       the-halal-guys-new-york-2
# 4   jVncyqXwlx_D9f2xZn05tg       the-metropolitan-museum-of-art-new-york-3
# 5   xOw4aafJRji9XomGunlvcQ                           central-park-new-york
# 6   WHRHK3S1mQc3PmhwsGRvbw                       bibble-and-sip-new-york-2
# 22  https://www.yelp.com/biz/taiyaki-nyc-new-york?...          2912
# 23  https://www.yelp.com/biz/brooklyn-bridge-brook...          1395
# 24  https://www.yelp.com/biz/two-little-red-hens-n...          2605
# 25  https://www.yelp.com/biz/jacobs-pickles-new-yo...          4289
# 26  https://www.yelp.com/biz/julianas-pizza-brookl...          2255
# 27  https://www.yelp.com/biz/buddakan-new-york?adj...          4017
# 28  https://www.yelp.com/biz/club-a-steakhouse-new...          2833
# 29  https://www.yelp.com/biz/joes-shanghai-new-yor...          6255
# 30  https://www.yelp.com/biz/am%C3%A9lie-new-york?...          2698
# 31  https://www.yelp.com/biz/russ-and-daughters-ne...          2270
# 32  https://www.yelp.com/biz/eataly-flatiron-new-y...          5641
# 33  https://www.yelp.com/biz/chinatown-ice-cream-f...          2794
# 34  https://www.yelp.com/biz/anytime-new-york?adju...          1434
# 35  https://www.yelp.com/biz/ippudo-westside-new-y...          3706
# 36  https://www.yelp.com/biz/eleven-madison-park-n...          2189
# 37  https://www.yelp.com/biz/spot-dessert-bar-new-...          3019
# 38  https://www.yelp.com/biz/lombardis-pizza-new-y...          6128
# 39  https://www.yelp.com/biz/del-friscos-double-ea...          3025
# 40  https://www.yelp.com/biz/upstate-craft-beer-an...          1873
# 41  https://www.yelp.com/biz/up-thai-new-york?adju...          2363
# 42  https://www.yelp.com/biz/rubirosa-new-york-2?a...          2305
# 43  https://www.yelp.com/biz/grand-central-termina...          1398
# 44  https://www.yelp.com/biz/top-thai-greenwich-ne...          1535
# 45  https://www.yelp.com/biz/rice-to-riches-new-yo...          3039
# 46  https://www.yelp.com/biz/abc-kitchen-new-york?...          2979
# 47  https://www.yelp.com/biz/mollys-cupcakes-new-y...          1680
# 48  https://www.yelp.com/biz/the-museum-of-modern-...          1994
# 49  https://www.yelp.com/biz/traif-brooklyn?adjust...          1881
#
#                                            categories  rating  \
# 0        [{'alias': 'bakeries', 'title': 'Bakeries'}]     4.5
# 1   [{'alias': 'delis', 'title': 'Delis'}, {'alias...     4.0
# 2              [{'alias': 'ramen', 'title': 'Ramen'}]     4.0
# 3   [{'alias': 'foodstands', 'title': 'Food Stands...     4.0
# 4   [{'alias': 'artmuseums', 'title': 'Art Museums'}]     4.5
# 5              [{'alias': 'parks', 'title': 'Parks'}]     5.0
# 6   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 7              [{'alias': 'tacos', 'title': 'Tacos'}]     4.5
# 8   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 9   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 10  [{'alias': 'bagels', 'title': 'Bagels'}, {'ali...     4.5
# 11  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 12  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 13  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 14             [{'alias': 'parks', 'title': 'Parks'}]     4.5
# 15       [{'alias': 'steak', 'title': 'Steakhouses'}]     4.0
# 16  [{'alias': 'donuts', 'title': 'Donuts'}, {'ali...     4.5
# 17         [{'alias': 'museums', 'title': 'Museums'}]     4.5
# 18  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.0
# 19  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     4.0
# 20             [{'alias': 'tacos', 'title': 'Tacos'}]     4.5
# 21  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.0
# 22  [{'alias': 'icecream', 'title': 'Ice Cream & F...     4.5
# 23  [{'alias': 'landmarks', 'title': 'Landmarks & ...     4.5
# 24  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.5
# 25  [{'alias': 'comfortfood', 'title': 'Comfort Fo...     4.0
# 26             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 27  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
# 28       [{'alias': 'steak', 'title': 'Steakhouses'}]     4.5
# 29  [{'alias': 'shanghainese', 'title': 'Shanghain...     4.0
# 30  [{'alias': 'french', 'title': 'French'}, {'ali...     4.5
# 31  [{'alias': 'bagels', 'title': 'Bagels'}, {'ali...     4.5
# 32  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 33  [{'alias': 'icecream', 'title': 'Ice Cream & F...     4.0
# 34  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 35             [{'alias': 'ramen', 'title': 'Ramen'}]     4.0
# 36  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 37  [{'alias': 'desserts', 'title': 'Desserts'}, {...     4.0
# 38             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 39  [{'alias': 'steak', 'title': 'Steakhouses'}, {...     4.5
# 40         [{'alias': 'seafood', 'title': 'Seafood'}]     4.5
# 41  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 42  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 43  [{'alias': 'landmarks', 'title': 'Landmarks & ...     4.5
# 44  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 45       [{'alias': 'desserts', 'title': 'Desserts'}]     4.0
# 46  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 47  [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.5
# 48  [{'alias': 'artmuseums', 'title': 'Art Museums'}]     4.5
# 49  [{'alias': 'newamerican', 'title': 'American (...     4.5
#
#                                           coordinates  \
# 0    {'latitude': 40.779961, 'longitude': -73.980299}
# 1   {'latitude': 40.722237, 'longitude': -73.9875259}
# 2      {'latitude': 40.73092, 'longitude': -73.99015}
# 3    {'latitude': 40.761861, 'longitude': -73.979306}
# 4    {'latitude': 40.779449, 'longitude': -73.963245}
# 5   {'latitude': 40.782418740809, 'longitude': -73...
# 6      {'latitude': 40.76282, 'longitude': -73.98518}
# 7   {'latitude': 40.7425547, 'longitude': -74.0060...
# 8   {'latitude': 40.7303859, 'longitude': -73.9860...
# 9   {'latitude': 40.72308755605564, 'longitude': -...
# 10  {'latitude': 40.7522683, 'longitude': -73.9910...
# 11     {'latitude': 40.73902, 'longitude': -73.99065}
# 12     {'latitude': 40.74007, 'longitude': -73.99344}
# 13     {'latitude': 40.73844, 'longitude': -73.98825}
# 14    {'latitude': 40.7396, 'longitude': -74.0084399}
# 15   {'latitude': 40.709945, 'longitude': -73.962478}
# 16   {'latitude': 40.716334, 'longitude': -73.988652}
# 17    {'latitude': 40.71143, 'longitude': -74.012481}
# 18   {'latitude': 40.721128, 'longitude': -73.983933}
# 19  {'latitude': 40.7417320034487, 'longitude': -7...
# 20  {'latitude': 40.7575067, 'longitude': -73.9877...
# 21     {'latitude': 40.72522, 'longitude': -74.00291}
# 22      {'latitude': 40.71789, 'longitude': -73.9988}
# 23  {'latitude': 40.7059677364821, 'longitude': -7...
# 24  {'latitude': 40.777528, 'longitude': -73.9517869}
# 25  {'latitude': 40.7866504411994, 'longitude': -7...
# 26  {'latitude': 40.7026153030093, 'longitude': -7...
# 27  {'latitude': 40.7422762672197, 'longitude': -7...
# 28     {'latitude': 40.76006, 'longitude': -73.96557}
# 29  {'latitude': 40.7156608, 'longitude': -73.9967...
# 30      {'latitude': 40.7327, 'longitude': -73.99766}
# 31  {'latitude': 40.722589, 'longitude': -73.98828...
# 32  {'latitude': 40.74195877796, 'longitude': -73....
# 33    {'latitude': 40.715452, 'longitude': -73.99818}
# 34     {'latitude': 40.74779, 'longitude': -73.98674}
# 35     {'latitude': 40.76344, 'longitude': -73.98661}
# 36  {'latitude': 40.7416907417333, 'longitude': -7...
# 37     {'latitude': 40.72939, 'longitude': -73.98892}
# 38  {'latitude': 40.7215934960083, 'longitude': -7...
# 39   {'latitude': 40.759412, 'longitude': -73.982221}
# 40   {'latitude': 40.726373, 'longitude': -73.986557}
# 41  {'latitude': 40.7698275926665, 'longitude': -7...
# 42   {'latitude': 40.722766, 'longitude': -73.996233}
# 43   {'latitude': 40.752793, 'longitude': -73.977165}
# 44   {'latitude': 40.729771, 'longitude': -73.999392}
# 45   {'latitude': 40.721845, 'longitude': -73.995802}
# 46   {'latitude': 40.737832, 'longitude': -73.989649}
# 47     {'latitude': 40.73014, 'longitude': -74.00248}
# 48   {'latitude': 40.761441, 'longitude': -73.977625}
# 49   {'latitude': 40.710658, 'longitude': -73.958872}
#
#                                   transactions price  \
# 0                                           []    $$
# 1                           [delivery, pickup]    $$
# 2                           [delivery, pickup]    $$
# 3                           [delivery, pickup]     $
# 4                                           []   NaN
# 5                                           []   NaN
# 6                           [delivery, pickup]     $
# 7                                           []     $
# 8                           [delivery, pickup]    $$
# 9                           [delivery, pickup]     $
# 10                          [delivery, pickup]     $
# 11                          [delivery, pickup]    $$
# 12                          [delivery, pickup]    $$
# 13                                          []  $$$$
# 14                                          []   NaN
# 15                                          []  $$$$
# 16                          [delivery, pickup]    $$
# 17                                          []   NaN
# 18                                  [delivery]    $$
# 19                                  [delivery]    $$
# 20                          [delivery, pickup]     $
# 21                                  [delivery]    $$
# 22                                  [delivery]     $
# 23                                          []   NaN
# 24                                          []    $$
# 25                          [delivery, pickup]    $$
# 26                                  [delivery]    $$
# 27                          [delivery, pickup]   $$$
# 28                          [delivery, pickup]   $$$
# 29                          [delivery, pickup]    $$
# 30  [delivery, restaurant_reservation, pickup]    $$
# 31                                  [delivery]    $$
# 32                          [delivery, pickup]    $$
# 33                                  [delivery]     $
# 34  [delivery, restaurant_reservation, pickup]    $$
# 35                          [delivery, pickup]    $$
# 36                                          []  $$$$
# 37                          [delivery, pickup]    $$
# 38                          [delivery, pickup]    $$
# 39                          [delivery, pickup]  $$$$
# 40          [delivery, restaurant_reservation]    $$
# 41                          [delivery, pickup]    $$
# 42                          [delivery, pickup]    $$
# 43                                          []   NaN
# 44                          [delivery, pickup]    $$
# 45                          [delivery, pickup]    $$
# 46                          [delivery, pickup]   $$$
# 47                          [delivery, pickup]    $$
# 48                                          []   NaN
# 49                          [delivery, pickup]   $$$
#
#                                              location         phone  \
# 0   {'address1': '167 W 74th St', 'address2': '', ...  +19174643769
# 1   {'address1': '205 E Houston St', 'address2': '...  +12122542246
# 2   {'address1': '65 4th Ave', 'address2': '', 'ad...  +12123880088
# 3   {'address1': 'W 53rd St', 'address2': None, 'a...  +13475271505
# 4   {'address1': '1000 5th Ave', 'address2': '', '...  +12125357710
# 5   {'address1': '14 E 60th St', 'address2': '', '...
# 6   {'address1': '253 W 51st St', 'address2': '', ...  +16466495116
# 7   {'address1': '75 9th Ave', 'address2': '', 'ad...
# 8   {'address1': '174 2nd Ave', 'address2': '', 'a...  +12122545370
# 9   {'address1': '27 Prince St', 'address2': None,...  +12129664100
# 10  {'address1': '225 W 35th St', 'address2': '', ...  +12125644409
# 11  {'address1': '5 E 19th St', 'address2': 'G Flo...  +12128029999
# 12  {'address1': '39 W 19th St', 'address2': '', '...  +16468337532
# 13  {'address1': '42 E 20th St', 'address2': '', '...  +12124770777
# 14  {'address1': '820 Washington St', 'address2': ...  +12122069922
# 15  {'address1': '178 Broadway', 'address2': '', '...  +17183877400
# 16  {'address1': '379 Grand St', 'address2': '', '...  +12125053700
# 17  {'address1': '180 Greenwich St', 'address2': '...  +12122665211
# 18  {'address1': '4 Clinton St', 'address2': '', '...  +16466026263
# 19  {'address1': 'E 23rd St Madison Avenue', 'addr...  +12128896600
# 20  {'address1': '229 W 43rd St', 'address2': '', ...  +12125744696
# 21  {'address1': '189 Spring St', 'address2': '', ...  +12122192773
# 22  {'address1': '119 Baxter St', 'address2': '', ...  +12129662882
# 23  {'address1': '334 Furman St', 'address2': None...  +17187246434
# 24  {'address1': '1652 2nd Ave', 'address2': None,...  +12124520476
# 25  {'address1': '509 Amsterdam Ave', 'address2': ...  +12124705566
# 26  {'address1': '19 Old Fulton St', 'address2': '...  +17185966700
# 27  {'address1': '75 9th Ave', 'address2': None, '...  +12129896699
# 28  {'address1': '240 E 58th St', 'address2': '', ...  +12126884190
# 29  {'address1': '46 Bowery St', 'address2': '', '...  +12122338888
# 30  {'address1': '22 W 8th St', 'address2': '', 'a...  +12125332962
# 31  {'address1': '179 E Houston St', 'address2': '...  +12124754880
# 32  {'address1': '200 5th Ave', 'address2': '', 'a...  +12122292560
# 33  {'address1': '65 Bayard St', 'address2': '', '...  +12126084170
# 34  {'address1': '23 W 32nd St', 'address2': 'Fl 3...  +16466697733
# 35  {'address1': '321 W 51st St', 'address2': None...  +12129742500
# 36  {'address1': '11 Madison Ave', 'address2': '',...  +12128890905
# 37  {'address1': '13 St Marks Pl', 'address2': '',...  +12126775670
# 38  {'address1': '32 Spring St', 'address2': '', '...  +12129417994
# 39  {'address1': '1221 Ave Of The Americas', 'addr...  +12125755129
# 40  {'address1': '95 1st Ave', 'address2': None, '...  +16467915400
# 41  {'address1': '1411 2nd Ave', 'address2': '', '...  +12122561188
# 42  {'address1': '235 Mulberry St', 'address2': ''...  +12129650500
# 43  {'address1': '89 E 42nd St', 'address2': None,...  +12123402583
# 44  {'address1': '235 Sullivan St', 'address2': ''...  +16467264418
# 45  {'address1': '37 Spring St', 'address2': '', '...  +12122740008
# 46  {'address1': '35 E 18th St', 'address2': '', '...  +12124755829
# 47  {'address1': '228 Bleecker St', 'address2': ''...  +12124142253
# 48  {'address1': '11 West 53rd St', 'address2': ''...  +12127089400
# 49  {'address1': '229 S 4th St', 'address2': '', '...  +13478449578
#
#      display_phone     distance
# 0   (917) 464-3769  8369.262425
# 1   (212) 254-2246  1952.370624
# 2   (212) 388-0088  2854.301267
# 3   (347) 527-1505  6399.019110
# 4   (212) 535-7710  8634.601734
# 5                   8893.835856
# 6   (646) 649-5116  6427.921252
# 7                   4244.358699
# 8   (212) 254-5370  2858.772941
# 9   (212) 966-4100  1961.877142
# 10  (212) 564-4409  5213.531501
# 11  (212) 802-9999  3744.570400
# 12  (646) 833-7532  3849.543868
# 13  (212) 477-0777  3702.807580
# 14  (212) 206-9922  3992.412193
# 15  (718) 387-7400  2728.016922
# 16  (212) 505-3700  1300.828491
# 17  (212) 266-5211  1671.270458
# 18  (646) 602-6263  1950.282830
# 19  (212) 889-6600  4067.639945
# 20  (212) 574-4696  5815.027424
# 21  (212) 219-2773  2316.930739
# 22  (212) 966-2882  1439.725809
# 23  (718) 724-6434   208.268972
# 24  (212) 452-0476  8778.875029
# 25  (212) 470-5566  9166.964738
# 26  (718) 596-6700   323.205063
# 27  (212) 989-6699  4190.079294
# 28  (212) 688-4190  6537.211374
# 29  (212) 233-8888  1153.948239
# 30  (212) 533-2962  3038.869903
# 31  (212) 475-4880  1972.496648
# 32  (212) 229-2560  4078.433354
# 33  (212) 608-4170  1159.965506
# 34  (646) 669-7733  4761.966726
# 35  (212) 974-2500  6486.789309
# 36  (212) 889-0905  4074.346398
# 37  (212) 677-5670  2697.523334
# 38  (212) 941-7994  1798.995978
# 39  (212) 575-5129  6086.466540
# 40  (646) 791-5400  2416.715359
# 41  (212) 256-1188  7796.912676
# 42  (212) 965-0500  1932.946770
# 43  (212) 340-2583  5459.111478
# 44  (646) 726-4418  2739.489773
# 45  (212) 274-0008  1828.038283
# 46  (212) 475-5829  3622.486228
# 47  (212) 414-2253  2828.812387
# 48  (212) 708-9400  6382.905321
# 49  (347) 844-9578  3041.420338

# %% [markdown]
# Note that location or latitude and longitude are the only required parameters. That said, you are free to pass as many parameters as you want such as:

# %%
url2 = 'https://api.yelp.com/v3/businesses/search'

headers2 = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params2 = {
                'location': 'NYC',
                'term' : 'pizza',
                'limit' : 50,
                'price' : "1,2,3,4",
                'open_now' : True,
                'radius'  : 1000
            }
response2 = requests.get(url2, headers=headers2, params=url_params2)

# %%
import pandas as pd
df2 = pd.DataFrame.from_dict(response2.json()['businesses'])
print(len(df2))
df2
# Out:
# 15
#                         id                                  alias  \
# 0   VG6Lhgcq5AHP-kklGTCbTQ                   love-and-dough-dumbo
# 1   xeC9vn3dxVVzAMR_aFwfXg                   il-brigante-new-york
# 2   MQ_a14GsdMrXsnt9mgqx_Q              dominos-pizza-new-york-35
# 3   iSD5QHURPylVUNWJjv50Pg              e-broadway-pizza-new-york
# 4   HcWm-9ZZu2_brnuRxN5Gpg                     tutt-cafe-brooklyn
# 5   I4LSdJd2Z8M6VNLhbX3aLA                     superfine-brooklyn
# 6   f7g3GhoQs9nQVTJEL2p48Q              gran-electrica-brooklyn-3
# 7   Edkx9frqYknN9ykTEqTVXg               miso-restaurant-brooklyn
# 8   9pVn9v3ETBV2RGX07FBENw     7-old-fulton-restaurant-brooklyn-2
# 9   rYlN-fY1D3HnXPbqAgCUYw              peas-and-pickles-brooklyn
# 10  SoBdWOxymmY5yKANn63UWw                           ozu-brooklyn
# 11  91tQ4ToReVVCA5MTJi9gfw               iron-chef-house-brooklyn
# 12  LpVbI-E9C-CSp7WhU5h2Iw         fishmarket-restaurant-new-york
# 13  3GIPU7bVND8mlepHGIgFmA  ali-baba-organic-marketplace-new-york
# 14  97q5nUQTuBo_h00XCxna2A     tasty-hand-pulled-noodles-new-york
#
#                             name  \
# 0                   Love & Dough
# 1                    IL Brigante
# 2                 Domino's Pizza
# 3               E Broadway Pizza
# 4                      Tutt Cafe
# 5                      Superfine
# 6                 Gran Electrica
# 7                Miso Restaurant
# 8        7 Old Fulton Restaurant
# 9                 Peas & Pickles
# 10                           Ozu
# 11               Iron Chef House
# 12         Fishmarket Restaurant
# 13  Ali Baba Organic Marketplace
# 14     Tasty Hand-Pulled Noodles
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/bvncuk...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/0G1IhF...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/yoE1b4...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/vIiUbJ...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/sS2AuA...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/a68hCk...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/vltMa2...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/HToh4a...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/YIKSHn...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/Dqm3er...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/T1Sdmm...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/zJbC6J...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/BxY50B...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/b3pEhr...      False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/S4YfmB...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/love-and-dough-dumbo?...           167
# 1   https://www.yelp.com/biz/il-brigante-new-york?...           412
# 2   https://www.yelp.com/biz/dominos-pizza-new-yor...            28
# 3   https://www.yelp.com/biz/e-broadway-pizza-new-...            13
# 4   https://www.yelp.com/biz/tutt-cafe-brooklyn?ad...           231
# 5   https://www.yelp.com/biz/superfine-brooklyn?ad...           469
# 6   https://www.yelp.com/biz/gran-electrica-brookl...           484
# 7   https://www.yelp.com/biz/miso-restaurant-brook...           113
# 8   https://www.yelp.com/biz/7-old-fulton-restaura...           283
# 9   https://www.yelp.com/biz/peas-and-pickles-broo...           123
# 10  https://www.yelp.com/biz/ozu-brooklyn?adjust_c...           263
# 11  https://www.yelp.com/biz/iron-chef-house-brook...           409
# 12  https://www.yelp.com/biz/fishmarket-restaurant...           549
# 13  https://www.yelp.com/biz/ali-baba-organic-mark...            63
# 14  https://www.yelp.com/biz/tasty-hand-pulled-noo...          1619
#
#                                            categories  rating  \
# 0   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.0
# 1          [{'alias': 'italian', 'title': 'Italian'}]     4.0
# 2   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     2.5
# 3   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     2.0
# 4   [{'alias': 'mideastern', 'title': 'Middle East...     4.0
# 5   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     3.5
# 6   [{'alias': 'mexican', 'title': 'Mexican'}, {'a...     3.5
# 7   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.0
# 8   [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     2.5
# 9   [{'alias': 'markets', 'title': 'Fruits & Veggi...     2.5
# 10  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 11        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.0
# 12  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 13  [{'alias': 'grocery', 'title': 'Grocery'}, {'a...     3.0
# 14  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 40.7030253, 'longitude': -73.9874...  [pickup, delivery]
# 1    {'latitude': 40.707492, 'longitude': -74.002571}  [pickup, delivery]
# 2      {'latitude': 40.71194, 'longitude': -73.99669}                  []
# 3       {'latitude': 40.7137, 'longitude': -73.99197}  [pickup, delivery]
# 4     {'latitude': 40.700188, 'longitude': -73.99322}  [pickup, delivery]
# 5    {'latitude': 40.702236, 'longitude': -73.987426}  [pickup, delivery]
# 6       {'latitude': 40.7027, 'longitude': -73.99314}  [pickup, delivery]
# 7   {'latitude': 40.7028045654297, 'longitude': -7...  [pickup, delivery]
# 8   {'latitude': 40.7029876708984, 'longitude': -7...          [delivery]
# 9   {'latitude': 40.7026999, 'longitude': -73.9894...                  []
# 10  {'latitude': 40.6974732130766, 'longitude': -7...  [pickup, delivery]
# 11  {'latitude': 40.6972664717136, 'longitude': -7...  [pickup, delivery]
# 12     {'latitude': 40.70717, 'longitude': -74.00192}          [delivery]
# 13  {'latitude': 40.7138025, 'longitude': -73.9988...  [pickup, delivery]
# 14      {'latitude': 40.7142, 'longitude': -73.99787}  [pickup, delivery]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '57 Pearl St', 'address2': '', 'a...  +13479873404
# 1     $$  {'address1': '214 Front St', 'address2': '', '...  +12122850222
# 2      $  {'address1': '45 Catherine St', 'address2': ''...  +12128024444
# 3      $  {'address1': '127 E Broadway', 'address2': '',...  +19172615501
# 4      $  {'address1': '47 Hicks St', 'address2': '', 'a...  +17187227777
# 5     $$  {'address1': '126 Front St', 'address2': '', '...  +17182439005
# 6     $$  {'address1': '5 Front St', 'address2': '', 'ad...  +17188522700
# 7     $$  {'address1': '40 Main St', 'address2': '', 'ad...  +17188588388
# 8     $$  {'address1': '7 Old Fulton St', 'address2': ''...  +17187970007
# 9     $$  {'address1': '55 Washington St', 'address2': '...  +17184888336
# 10    $$  {'address1': '78 Clark St', 'address2': '', 'a...  +17187973288
# 11    $$  {'address1': '92 Clark St', 'address2': '', 'a...  +17188588517
# 12    $$  {'address1': '111 South St', 'address2': '', '...  +19173638101
# 13     $  {'address1': '1 Mott St', 'address2': '', 'add...  +12122335797
# 14     $  {'address1': '1 Doyers St', 'address2': '', 'a...  +12127911817
#
#      display_phone     distance
# 0   (347) 987-3404   638.156959
# 1   (212) 285-0222   738.248264
# 2   (212) 802-4444   749.968202
# 3   (917) 261-5501   938.182405
# 4   (718) 722-7777   589.736983
# 5   (718) 243-9005   684.569142
# 6   (718) 852-2700   321.695510
# 7   (718) 858-8388   412.847690
# 8   (718) 797-0007   279.635091
# 9   (718) 488-8336   521.617027
# 10  (718) 797-3288   896.102668
# 11  (718) 858-8517   920.553743
# 12  (917) 363-8101   671.078456
# 13  (212) 233-5797  1004.710534
# 14  (212) 791-1817  1017.728241

# %%
df2['categories'][13]
# Out:
# [{'alias': 'grocery', 'title': 'Grocery'},
#  {'alias': 'organic_stores', 'title': 'Organic Stores'},
#  {'alias': 'tradamerican', 'title': 'American (Traditional)'}]

# %% [markdown]
# The final important note is how some of the parameters have alternative formats. For example, `limit` is an integer and `open_now` is a boolean according to the documentation. Following these conventions is essential to receiving valid responses.
#
# # Summary
#
# Congratulations! Not only have you seen an API now, you've also practiced sifting through the documentation. The last piece in working with APIs is developing a more solid understanding of JSON files; the data format typically returned by modern APIs. Take some additional time and familiarize yourself with some further aspects of the documentation which you may wish to investigate in the upcoming lab!
